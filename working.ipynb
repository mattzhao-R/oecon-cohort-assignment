# %%
import time
import csv
import re

import pandas as pd
import numpy as np

# %% [markdown]
# ## Import and Tidy Data from Form

# %%
df = pd.read_csv('./data/data_1.csv')

# %%
df = df[[col for col in df.columns if (("Preferences" in col) | ("Email" in col) | ("Name" in col) | ("Year" in col))]]

# %%
df.columns = list(df.columns[0:3]) + [re.split('\[|\]',name)[1] for name in df.columns[3:]]
cohort_names = list(df.columns[3:])

# %%
for col in cohort_names:
    df[col] = pd.to_numeric(df[col].str.extract('(\d)', expand=False).str.strip())

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#                    Email Address    First Name        Last Name  \
# 0       gwenythross@uchicago.edu       Gwenyth             Ross
# 1       yasminemara@uchicago.edu        Yasmin           Hashem
# 2          brycklen@uchicago.edu      Brycklen           Arnold
# 3      alecboyajian@uchicago.edu          Alec         Boyajian
# 4        victorqian@uchicago.edu        Victor             Qian
# ..                           ...           ...              ...
# 58             panc@uchicago.edu  Christopher               Pan
# 59    tanyadholakia@uchicago.edu         Tanya         Dholakia
# 60  malvarezdemalde@uchicago.edu        Matias  Alvarez Demalde
# 61          bermann@uchicago.edu      Benjamin          Bermann
# 62   akshayjoglekar@uchicago.edu        Akshay         Joglekar
#
#     Economic History  Development Economics  Economics of Inequality  \
# 0                4.0                    3.0                      2.0
# 1                4.0                    1.0                      2.0
# 2                1.0                    0.0                      2.0
# 3                2.0                    1.0                      4.0
# 4                3.0                    4.0                      1.0
# ..               ...                    ...                      ...
# 58               3.0                    1.0                      4.0
# 59               4.0                    1.0                      0.0
# 60               2.0                    1.0                      4.0
# 61               4.0                    1.0                      2.0
# 62               4.0                    3.0                      2.0
#
#     Economics and Machine Learning
# 0                              1.0
# 1                              3.0
# 2                              4.0
# 3                              0.0
# 4                              2.0
# ..                             ...
# 58                             2.0
# 59                             2.0
# 60                             3.0
# 61                             3.0
# 62                             1.0
#
# [63 rows x 7 columns]

# %% [markdown]
# ## Sort Students
#
# Fill each cohort with people who selected as first choice then cut down and re-sort

# %%
cohorts = {name:[] for name in cohort_names}

# %%
temp = df.copy()
for rank in range(1,len(cohort_names)+1):
    for name in cohort_names:
        for row in range(0,temp.shape[0]):
            if ((pd.notna(temp.loc[row,'Email Address'])) and (len(cohorts[name]) < 20) and (temp[name][row] == rank)):
                cohorts[name].append(temp['Email Address'][row])
                temp.loc[row,'Email Address'] = np.nan

# %%
print(list(cohorts.keys()))
print([len(cohorts[key]) for key in cohorts.keys()])
# Out:
# ['Economic History', 'Development Economics', 'Economics of Inequality', 'Economics and Machine Learning']
# [13, 20, 9, 20]

# %%
for c in cohorts.keys():
    pref = {email:rank for email,rank in zip(df['Email Address'],df[c])}
    print(c,': ', pd.Series(cohorts[c]).replace(pref).unique())
# Out:
# Economic History :  [1. 2. 4.]
# Development Economics :  [1.]
# Economics of Inequality :  [1. 2.]
# Economics and Machine Learning :  [1. 2.]

# %%
econ_hist = {email:email for email in cohorts['Economic History']}

# %%
pref_hist = {email:rank for email,rank in zip(df['Email Address'],df['Economic History'])}
for mail in econ_hist.keys():
    econ_hist[mail] = pref_hist[mail]

# %%
econ_hist
# Out:
# {'brycklen@uchicago.edu': 1.0,
#  'kmeyyappan@uchicago.edu': 1.0,
#  'cbuyalos@uchicago.edu': 1.0,
#  'ashivaram27@uchicago.edu': 1.0,
#  'lilychen@uchicago.edu': 1.0,
#  'gabicampos@uchicago.edu': 1.0,
#  'jhiverson@uchicago.edu': 1.0,
#  'adrakopoulou@uchicago.edu': 1.0,
#  'raylee@uchicago.edu': 1.0,
#  'rachelalper@uchicago.edu': 1.0,
#  'shivsawhney@uchicago.edu': 2.0,
#  'malvarezdemalde@uchicago.edu': 2.0,
#  'tanyadholakia@uchicago.edu': 4.0}

# %%
df[df['Email Address'].str.contains('tanyadholakia')]
# Out:
#                  Email Address First Name Last Name  Economic History  \
# 59  tanyadholakia@uchicago.edu      Tanya  Dholakia               4.0
#
#     Development Economics  Economics of Inequality  \
# 59                    1.0                      0.0
#
#     Economics and Machine Learning
# 59                             2.0

# %%
cohort_assignments = pd.DataFrame(dict([(k,pd.Series(v)) for k,v in cohorts.items()]))

# %%
for cohort, emails in cohorts.items():
    indiv_assign = df[df['Email Address'].isin(emails)]
    path = './assignments/' + '_'.join(cohort.lower().split(' ')) + '.csv'
    indiv_assign.to_csv(path_or_buf=path)
    print(path)
# Out:
# ./assignments/economic_history.csv
# ./assignments/development_economics.csv
# ./assignments/economics_of_inequality.csv
# ./assignments/economics_and_machine_learning.csv

# %%
cohort_assignments
# Out:
#                 Economic History          Development Economics  \
# 0          brycklen@uchicago.edu       yasminemara@uchicago.edu
# 1        kmeyyappan@uchicago.edu      alecboyajian@uchicago.edu
# 2          cbuyalos@uchicago.edu         ghwhorton@uchicago.edu
# 3       ashivaram27@uchicago.edu  avalenzuelapidal@uchicago.edu
# 4          lilychen@uchicago.edu          hilfersd@uchicago.edu
# 5        gabicampos@uchicago.edu           graceoh@uchicago.edu
# 6         jhiverson@uchicago.edu        jzmiller97@uchicago.edu
# 7      adrakopoulou@uchicago.edu          lucashou@uchicago.edu
# 8            raylee@uchicago.edu         sitongliu@uchicago.edu
# 9       rachelalper@uchicago.edu           msnasir@uchicago.edu
# 10      shivsawhney@uchicago.edu            aoneil@uchicago.edu
# 11  malvarezdemalde@uchicago.edu    katherinepapen@uchicago.edu
# 12    tanyadholakia@uchicago.edu           yunakim@uchicago.edu
# 13                           NaN            ewoldu@uchicago.edu
# 14                           NaN      georgianalxy@uchicago.edu
# 15                           NaN        rachelmaya@uchicago.edu
# 16                           NaN         vpotineni@uchicago.edu
# 17                           NaN       mehakrattan@uchicago.edu
# 18                           NaN        ffsandoval@uchicago.edu
# 19                           NaN           sjdixon@uchicago.edu
#
#     Economics of Inequality Economics and Machine Learning
# 0   victorqian@uchicago.edu       gwenythross@uchicago.edu
# 1    sycalvind@uchicago.edu        gasparolea@uchicago.edu
# 2       iwang1@uchicago.edu           locdang@uchicago.edu
# 3      edosani@uchicago.edu            aaronz@uchicago.edu
# 4         maxz@uchicago.edu    owenrhumphries@uchicago.edu
# 5      jxiong3@uchicago.edu           kaizewu@uchicago.edu
# 6    connollyb@uchicago.edu            nmkhan@uchicago.edu
# 7       alsong@uchicago.edu        ethanjiang@uchicago.edu
# 8      bermann@uchicago.edu            epan02@uchicago.edu
# 9                       NaN  nicholaschen2003@uchicago.edu
# 10                      NaN      yusufjohnson@uchicago.edu
# 11                      NaN        zach123456@uchicago.edu
# 12                      NaN          justinjk@uchicago.edu
# 13                      NaN        michaelkfc@uchicago.edu
# 14                      NaN        prakhars03@uchicago.edu
# 15                      NaN        jasonjchen@uchicago.edu
# 16                      NaN       mfernandes1@uchicago.edu
# 17                      NaN    akshayjoglekar@uchicago.edu
# 18                      NaN        kduggirala@uchicago.edu
# 19                      NaN              panc@uchicago.edu

# %%
np.array([len(cohort) for cohort in cohorts.values()]).sum()
# Out:
# 62

# %%
assigned = sum(cohorts.values(), [])

# %%
set(assigned).symmetric_difference(set(df['Email Address'].tolist()))
# Out:
# {'giyoung@uchicago.edu'}

# %%
df[df['Email Address'].str.contains('tanyadholakia')]

# %%
leftovers = list(set(assigned).symmetric_difference(set(df['Email Address'].tolist())))

# %%
if len(leftovers) != 0:
    df[df['Email Address'].isin(leftovers)].to_csv(path_or_buf='./assignments/leftovers.csv')

# %%
df[df['Email Address'].isin(leftovers)]
# Out:
#            Email Address First Name Last Name  Economic History  \
# 53  giyoung@uchicago.edu    Giyoung      Kwon               0.0
#
#     Development Economics  Economics of Inequality  \
# 53                    1.0                      0.0
#
#     Economics and Machine Learning
# 53                             0.0

# %% [markdown]
# ## Test

# %%
df = pd.read_csv('./data/data_1.csv')
df = df[[col for col in df.columns if (("Preferences" in col) | ("Email" in col) | ("Name" in col) | ("Year" in col))]]
df.columns = list(df.columns[0:4]) + [re.split('\[|\]',name)[1] for name in df.columns[4:]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/fp/_7x5x4s175369fk6b5b5xhy40000gn/T/ipykernel_77559/2585784553.py in <module>
#       1 df = pd.read_csv('./data/data_1.csv')
#       2 df = df[[col for col in df.columns if (("Preferences" in col) | ("Email" in col) | ("Name" in col) | ("Year" in col))]]
# ----> 3 df.columns = list(df.columns[0:3]) + [re.split('\[|\]',name)[1] for name in df.columns[3:]]
#
# /var/folders/fp/_7x5x4s175369fk6b5b5xhy40000gn/T/ipykernel_77559/2585784553.py in <listcomp>(.0)
#       1 df = pd.read_csv('./data/data_1.csv')
#       2 df = df[[col for col in df.columns if (("Preferences" in col) | ("Email" in col) | ("Name" in col) | ("Year" in col))]]
# ----> 3 df.columns = list(df.columns[0:3]) + [re.split('\[|\]',name)[1] for name in df.columns[3:]]
#
# IndexError: list index out of range

# %%
df
# Out:
#                 Email Address First Name  Last Name Year  \
# 0    gwenythross@uchicago.edu    Gwenyth       Ross    2
# 1    yasminemara@uchicago.edu     Yasmin     Hashem    3
# 2       brycklen@uchicago.edu   Brycklen     Arnold    1
# 3   alecboyajian@uchicago.edu       Alec   Boyajian    1
# 4     victorqian@uchicago.edu     Victor       Qian    2
# ..                        ...        ...        ...  ...
# 63    gflegueras@uchicago.edu    Gianina  Flegueras    2
# 64     rmguthrie@uchicago.edu       Ryan    Guthrie    1
# 65     laraburuk@uchicago.edu       Lara      Buruk    1
# 66    bettyerose@uchicago.edu     Bettye  Igbenebor    2
# 67     veersethi@uchicago.edu       Veer      Sethi    1
#
#    Please Rank Your Cohort Preferences  [Economic History]  \
# 0                                     4 (Last Choice)
# 1                                     4 (Last Choice)
# 2                                    1 (First Choice)
# 3                                                   2
# 4                                                   3
# ..                                                ...
# 63                                      Cannot Attend
# 64                                      Cannot Attend
# 65                                    4 (Last Choice)
# 66                                    4 (Last Choice)
# 67                                                  3
#
#    Please Rank Your Cohort Preferences  [Development Economics]  \
# 0                                                   3
# 1                                    1 (First Choice)
# 2                                       Cannot Attend
# 3                                    1 (First Choice)
# 4                                     4 (Last Choice)
# ..                                                ...
# 63                                   1 (First Choice)
# 64                                   1 (First Choice)
# 65                                                  2
# 66                                   1 (First Choice)
# 67                                                  2
#
#    Please Rank Your Cohort Preferences  [Economics of Inequality]  \
# 0                                                   2
# 1                                                   2
# 2                                                   2
# 3                                     4 (Last Choice)
# 4                                    1 (First Choice)
# ..                                                ...
# 63                                                  2
# 64                                      Cannot Attend
# 65                                                  3
# 66                                                  3
# 67                                      Cannot Attend
#
#    Please Rank Your Cohort Preferences  [Economics and Machine Learning]
# 0                                    1 (First Choice)
# 1                                                   3
# 2                                     4 (Last Choice)
# 3                                       Cannot Attend
# 4                                                   2
# ..                                                ...
# 63                                      Cannot Attend
# 64                                      Cannot Attend
# 65                                   1 (First Choice)
# 66                                                  2
# 67                                   1 (First Choice)
#
# [68 rows x 8 columns]
